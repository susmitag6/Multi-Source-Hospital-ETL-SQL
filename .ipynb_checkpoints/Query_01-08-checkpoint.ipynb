# %%
import sqlite3
conn = sqlite3.connect('hospital_compare.db')

# %%
cursor = conn.cursor()

# %%
cursor.execute("""
SELECT name 
FROM sqlite_master 
WHERE type='table';
""")

tables = cursor.fetchall()

tables
# Out:
# [('hospitals',),
#  ('measures',),
#  ('hospital_measures',),
#  ('hac_payment_reduction',)]

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/susmita/bin/anaconda3/envs/Hypothesis_Testing/lib/python3.11/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/susmita/bin/anaconda3/envs/Hypothesis_Testing/lib/python3.11/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/susmita/bin/anaconda3/envs/Hypothesis_Testing/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/susmita/bin/anaconda3/envs/Hypothesis_Testing/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_sql_query("SELECT * FROM hospitals", conn)

df.head()
# Out:
#   facility_id                    hospital_name                     address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1      010005         MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 2      010006     NORTH ALABAMA MEDICAL CENTER          205 MARENGO STREET
# 3      010007         MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4      010008      CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        city state zip_code      county phone_number hospital_type  \
# 0    DOTHAN    AL    36301     HOUSTON   3347938701    Acute Care
# 1      BOAZ    AL    35957    MARSHALL   2565938310    Acute Care
# 2  FLORENCE    AL    35631  LAUDERDALE   2567688400    Acute Care
# 3       OPP    AL    36467   COVINGTON   3344933541    Acute Care
# 4   LUVERNE    AL    36049    CRENSHAW   3343353374    Acute Care
#
#                             hospital_ownership  emergency_services   beds  \
# 0  Government - Hospital District or Authority                 1.0  377.0
# 1  Government - Hospital District or Authority                 1.0  193.0
# 2  Government - Hospital District or Authority                 1.0  314.0
# 3               Voluntary Non-Profit - Private                 1.0   64.0
# 4                                  Proprietary                 1.0   49.0
#
#          lat        lon  in_2011_data  in_2022_data  \
# 0  31.214058 -85.361725             1             1
# 1        NaN        NaN             1             1
# 2  34.802756 -87.652191             1             1
# 3  31.291972 -86.255415             1             1
# 4  31.692595 -86.266156             1             1
#
#    has_ownership_conflict_2022
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
import pandas as pd

df = pd.read_sql_query("SELECT * FROM measures", conn)

df.head()
# Out:
#                              measure_id  \
# 0     LEGACY2011_MORTALITY_HEART_ATTACK
# 1    LEGACY2011_MORTALITY_HEART_FAILURE
# 2        LEGACY2011_MORTALITY_PNEUMONIA
# 3   LEGACY2011_READMISSION_HEART_ATTACK
# 4  LEGACY2011_READMISSION_HEART_FAILURE
#
#                               measure_name        topic  file_year
# 0     Mortality Rate - Heart Attack (2011)  Legacy_2011       2011
# 1    Mortality Rate - Heart Failure (2011)  Legacy_2011       2011
# 2        Mortality Rate - Pneumonia (2011)  Legacy_2011       2011
# 3   Readmission Rate - Heart Attack (2011)  Legacy_2011       2011
# 4  Readmission Rate - Heart Failure (2011)  Legacy_2011       2011

# %%
import pandas as pd

df = pd.read_sql_query("SELECT * FROM hospital_measures", conn)

df.head()
# Out:
#   facility_id                         measure_id  file_year  value
# 0      010001  LEGACY2011_MORTALITY_HEART_ATTACK       2011   14.3
# 1      010005  LEGACY2011_MORTALITY_HEART_ATTACK       2011   18.5
# 2      010006  LEGACY2011_MORTALITY_HEART_ATTACK       2011   18.1
# 3      010007  LEGACY2011_MORTALITY_HEART_ATTACK       2011    NaN
# 4      010008  LEGACY2011_MORTALITY_HEART_ATTACK       2011    NaN

# %%
import pandas as pd

df = pd.read_sql_query("SELECT * FROM hac_payment_reduction", conn)

df.head()
# Out:
#   facility_id  file_year payment_reduction
# 0      010001       2022                No
# 1      010005       2022               Yes
# 2      010006       2022                No
# 3      010007       2022                No
# 4      010008       2022                No

# %%
"""============================================================================
1. Rank U.S. states by average AMI (heart attack)
============================================================================"""
with open('sql/queries/01_state_mortality_rankings_2022.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
#   state  avg_mortality_rate  hospitals_reporting  national_avg  \
# 0    MS               13.47                   23         12.35
# 1    AR               13.07                   26         12.35
# 2    LA               12.99                   34         12.35
# 3    AL               12.92                   30         12.35
# 4    VT               12.91                    8         12.35
#
#    diff_vs_national  worst_to_best_rank
# 0              1.12                   1
# 1              0.72                   2
# 2              0.64                   3
# 3              0.57                   4
# 4              0.56                   5

# %%
"""=================================================================================
2. Compare the AMI (heart attack) mortality rate of hospitals across the 11-year gap.
===================================================================================="""
with open('sql/queries/02_then_vs_now_2011_2022.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
#                                hospital_name state  mortality_rate_2011  \
# 0  OSF LITTLE COMPANY OF MARY MEDICAL CENTER    IL                 12.1
# 1      METHODIST MEDICAL CENTER OF OAK RIDGE    TN                 12.8
# 2                   HOLY NAME MEDICAL CENTER    NJ                 12.0
# 3       AVERA HEART HOSPITAL OF SOUTH DAKOTA    SD                 10.5
# 4              ANDERSON REGIONAL MEDICAL CTR    MS                 14.1
#
#    mortality_rate_2022  change_in_rate
# 0                 14.4             2.3
# 1                 14.9             2.1
# 2                 14.0             2.0
# 3                 12.5             2.0
# 4                 16.0             1.9

# %%
"""============================================================================
3. Hospitals that rank in the WORST national quartile on BOTH MRSA and AMI
============================================================================"""
with open('sql/queries/03_cross_topic_worst_quartile.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
#                            hospital_name state  mrsa_sir  ami_mortality_rate
# 0          T J SAMSON COMMUNITY HOSPITAL    KY     7.725                13.7
# 1                    MERIT HEALTH WESLEY    MS     6.266                13.7
# 2    COFFEE REGIONAL MEDICAL CENTER, INC    GA     5.530                14.4
# 3         SHASTA REGIONAL MEDICAL CENTER    CA     5.168                14.3
# 4  HIGHLANDS ARH REGIONAL MEDICAL CENTER    KY     4.972                13.4

# %%
"""================================================================================
4. Mortality outcomes across all 4 Complications & Deaths conditions at once from 2022
================================================================================"""
with open('sql/queries/04_ownership_vs_outcomes.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
#                             hospital_ownership  num_hospitals  \
# 0                           Government - Local            217
# 1  Government - Hospital District or Authority            289
# 2                           Government - State             42
# 3                                  Proprietary            523
# 4                 Voluntary Non-Profit - Other            351
#
#    avg_ami_mortality  avg_hf_mortality  avg_copd_mortality  \
# 0              12.70             12.13                8.71
# 1              12.62             11.86                8.82
# 2              12.54             10.95                8.17
# 3              12.43             11.20                8.49
# 4              12.41             11.35                8.39
#
#    avg_stroke_mortality
# 0                 14.32
# 1                 14.30
# 2                 13.42
# 3                 13.35
# 4                 13.54

# %%
"""============================================================================
5. Data quality audit
============================================================================"""
with open('sql/queries/05_data_completeness_by_topic.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
#                             topic  file_year  total_cells  reported  missing  \
# 0       Timely_and_Effective_Care       2022       133230     73640    59590
# 1  Readmissions_Reduction_Program       2022        90210     60531    29679
# 2        Complications_and_Deaths       2022        16705     11302     5403
# 3       Payment_and_Value_of_Care       2022        29896     21758     8138
# 4                            HAIs       2022       102576     76547    26029
#
#    pct_missing
# 0         44.7
# 1         32.9
# 2         32.3
# 3         27.2
# 4         25.4

# %%
"""============================================================================
6. Rank U.S. states by average AMI (heart attack)
============================================================================"""
import pandas as pd

with open('sql/queries/06_hac_penalty_vs_infections.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
#   payment_reduction  num_hospitals  avg_clabsi_sir  avg_cauti_sir  \
# 0                No           2360           1.059          0.873
# 1               Yes            764           1.294          1.004
#
#    avg_mrsa_sir
# 0         1.110
# 1         1.225

# %%
"""============================================================================
7. Rank U.S. states by average AMI (heart attack)
============================================================================"""
with open('sql/queries/07_cross_file_consistency_check.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
# Empty DataFrame
# Columns: [hospital_name, state, has_ownership_conflict_2022]
# Index: []

# %%
"""============================================================================
8. Rank U.S. states by average AMI (heart attack)
============================================================================"""

with open('sql/queries/08_topic_coverage_by_state.sql', 'r') as file:
    query = file.read()

df = pd.read_sql_query(query, conn)

df.head(5)
# Out:
#   state  avg_topics_reported  num_hospitals
# 0    NJ                 5.92             64
# 1    MA                 5.69             59
# 2    MD                 5.64             47
# 3    FL                 5.56            182
# 4    SC                 5.51             59
